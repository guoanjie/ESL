# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from datasets.mixture import plot
from models import NaturalCubicSplineBasis

# %%
plot(Pipeline([
    ('ncs', NaturalCubicSplineBasis(dof=3)),
    ('scale', StandardScaler()),
    ('logistic', LogisticRegression(C=100)),
]))

# %%
plot(Pipeline([
    ('ncs', NaturalCubicSplineBasis(dof=3, tensor_product=True)),
    ('scale', StandardScaler()),
    ('logistic', LogisticRegression(C=100, max_iter=1000))]
))
