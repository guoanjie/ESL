# %%
import matplotlib.pyplot as plt

from datasets.zip import X

# %%
nrows = 6
ncols = 10
fig, axs = plt.subplots(nrows=nrows, ncols=ncols)

for r in range(nrows):
    for c in range(ncols):
        axs[r][c].imshow(X[c][r], cmap='gray_r')
        axs[r][c].axis('off')
