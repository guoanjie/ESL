# %%
import matplotlib.pyplot as plt
import seaborn as sns

from datasets.nci import X

# %%
n = 100
f, ax = plt.subplots(figsize=(.1 * X.shape[1], .1 * n))
sns.heatmap(X.head(n=n), cmap="coolwarm", robust=True, cbar=False, ax=ax);
