# %%
import numpy as np
import pandas as pd

from datasets.prostate import X_train

# %%
pd.set_option('precision', 3)
X_train.corr().mask(np.triu(np.ones(X_train.shape[1])).astype(bool)).iloc[1:, :-1]
# Out:
#          lcavol  lweight    age   lbph    svi    lcp  gleason
# lweight   0.300      NaN    NaN    NaN    NaN    NaN      NaN
# age       0.286    0.317    NaN    NaN    NaN    NaN      NaN
# lbph      0.063    0.437  0.287    NaN    NaN    NaN      NaN
# svi       0.593    0.181  0.129 -0.139    NaN    NaN      NaN
# lcp       0.692    0.157  0.173 -0.089  0.671    NaN      NaN
# gleason   0.426    0.024  0.366  0.033  0.307  0.476      NaN
# pgg45     0.483    0.074  0.276 -0.030  0.481  0.663    0.757
